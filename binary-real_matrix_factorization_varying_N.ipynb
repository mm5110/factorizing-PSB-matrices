# %% [markdown]
# # Factorizing PSB matrices - varying k/n

# %% [markdown]
# ## Supporting Functions
#
# ### Functions for generating and checking data

# %%
# IMPORTS
import numpy as np
import copy
import matplotlib.pyplot as plt
from timeit import default_timer as timer
from numpy import linalg as LA


# DATA GENERATION AND PERFORMANCE CHECKING FUNCTIONS
def generate_latent(n,k,c1,c2):
    b = c2-c1
    a = c1/b
    x = np.zeros(n)
    locs = np.random.permutation(n)[:k]
    x[locs] = 1
    signs = np.sign(np.random.randn(k))
    vals = b*(np.random.rand(k)+a)
    x[locs] = x[locs]*vals*signs
    return x

def generate_exp_dictionary1(m,n,d):
    A = np.zeros((m,n))
    for i in range(n):
        locs = np.random.permutation(m)[:d]
        A[locs,i] = 1
    return A

def generate_exp_dictionary2(m,n,d):
    A = np.zeros((m,n))
    alpha = int(np.floor(m/d))
    c = 0
    while c<n:
        perm = np.random.permutation(m)
        zeta = min(n-c, alpha)
        for j in range(zeta):
            locs = perm[j*d:(j+1)*d]
            A[locs,c] = 1
            c = c+1
    return A

def check_dictionary(eps,n,d,A):
    t = (1-4*eps)*d
    mu_A = np.max(np.transpose(A)@A - d*np.identity(n))
    if mu_A >= t:
        print("Generation error, A is not expander for this value of epsilon, mu_A = ", str.format('{0:.2f}', mu_A),", tau = ", str.format('{0:.2f}', t), ".")
        passed = False
    else:
        print("A passes coherence test, mu_A = ", str.format('{0:.2f}', mu_A),", tau = ", str.format('{0:.2f}', t), ".")
        passed = True
    return passed  
        
def check_recon_A(A,A_rec,d,eps,n):
    print("Checking reconstruction of A.")
    col_sum = sum(A_rec)
    print(str.format('{0:.1f}',100*len(col_sum[col_sum==d])/n), "% of columns fully formed.")
    print(str.format('{0:.1f}',100*(n - len(col_sum[col_sum==d]) - len(col_sum[col_sum==0]))/n) , "% of columns partially formed.")
    print(str.format('{0:.1f}', 100*len(col_sum[col_sum==0])/n), "% of columns have no entries.")
    overlaps = np.transpose(A_rec)@A
    A_rec_col, A_col = np.where(overlaps>(1-4*eps)*d)
    if len(col_sum[col_sum==0])<n:
        print(str.format('{0:.1f}', 100*len(A_rec_col)/(n - len(col_sum[col_sum==0]))), "% of reconstructed (fully or partially) columns match with a column in target matrix.")  
    error = 0
    missing = 0
    P = np.zeros((n,n))
    for i in range(len(A_rec_col)):
        diff = A_rec[:, A_rec_col[i]] - A[:,A_col[i]]
        error = error + sum(abs(diff[diff==1]))
        missing = missing + sum(abs(diff[diff==-1]))
        P[A_col[i], A_rec_col[i]] = 1
    print(str.format('{0:.0f}', 100*(missing+d*n-len(A_rec_col)*d)/(d*n)), "% of entries missing in total.")
    print(str.format('{0:.0f}', missing), "entries missing in matched columns.")
    print(str.format('{0:.0f}', error), "entries wrong in matched columns.")
    return P
    
def check_recon_X(X,X_rec,P,N,k,n):
    X_perm = P@X_rec
    print("Checking the values of X recovered.")
    tol = 10**-6
    total_entries = N*k
    total_entries_recovered = 0
    correct_loc_correct_val = 0
    correct_loc_wrong_val = 0
    wrong_loc = 0
    missing = 0
    passed = True
    for i in range(N):
        for j in range(n):
            if abs(X[j,i])>tol and abs(X_perm[j,i])>tol:
                error = abs(X[j,i] - X_perm[j,i])
                if error < tol:
                    correct_loc_correct_val +=1
                else:
                    correct_loc_wrong_val += 1
                    print("Column number = ", i, ", row number = ", j, ", true value = ", X[j,i], "value found = ", X_perm[j,i])
            elif abs(X[j,i])>tol and abs(X_perm[j,i])<tol:
                missing += 1
            elif abs(X[j,i])<tol and abs(X_perm[j,i])>tol:
                wrong_loc += 1
    print(str.format('{0:.1f}', 100*(correct_loc_correct_val/total_entries)), "% of entries correctly recovered.")
    print(str.format('{0:.1f}', 100*(correct_loc_wrong_val/total_entries)), "% of entries in correct location but have wrong value for location.")
    print(str.format('{0:.1f}', 100*(missing/total_entries)), "% of entries missing.")
    return X_perm

# %% [markdown]
# ### Auxillary functions

# %%
# USED IN BOTH EXPERIMENTS 1 and 2
def xps2(y,x_vals,x_locs,A_rec,m,eps,d,k):
    tol1 = 10**-8
    tol2 = 10**-8
    y_copy = copy.deepcopy(y)
    t = (1-2*eps)*d
    z1 = len(y_copy);
    W = np.zeros((m,k))
    vals = np.zeros(k)
    q = 0
    for i in range(z1):
        if np.abs(y_copy[i])> tol1:
            locs = list()
            locs.append(i)
            for j in range(i+1, m):
                if np.abs(y_copy[j] - y_copy[i]) < tol2:
                    locs.append(j)
                    y_copy[j] = 0
            match = np.where(y_copy[i]==x_vals)[0]
            if not match:
                if len(locs)>t:
                    W[locs,q] = 1
                    vals[q] = y_copy[i]
                    q = q+1
            elif len(match)==1:
                A_rec[locs, x_locs[match[0]]] = 1
            else:
                print('ERROR - column value matches with more than 1 singleton value already extracted')
        y_copy[i] = 0
    W = W[:,:q]
    vals = vals[:q]
    return [W, A_rec, vals, q]

def process_column2(y, A_rec, x, m, eps, d, k, c, dpid):
    exit_flag = True
    tau = (1-4*eps)*d
    x_locs = np.nonzero(x)[0]
    x_vals = np.zeros(len(x_locs))
    for i in range(len(x_locs)):
        x_vals[i] = x[x_locs[i]]  
    [W, A_rec, vals, q] = xps2(y,x_vals,x_locs,A_rec,m,eps,d,k)
    if q > 0:
        match_check = np.zeros(q) 
        match_col_id = -0.5*np.ones(q)
        data_id = dpid*np.ones(q)          
        if c > 0:           
            matches = np.transpose(W)@A_rec
            matches[matches<=tau] = 0
            matches[matches>tau] = 1
            num_matches = matches.sum(axis=1)
            col_ind = matches@np.arange(c)           
            for i in range(q):
                if num_matches[i] == 0:
                    if c>=n:
                        print("Error: trying to add new column which exceeds total number of columns")
                        exit_flag==False
                elif num_matches[i] == 1:
                    match_check[i] = 1                   
                    z = int(col_ind[i])
                    match_col_id[i] = z
                elif num_matches[i] > 1:
                    print("Error: partial support matches with ", num_matches[i]," partially reconstructed columns of A.")
                    exit_flag = False
    else:
        exit_flag = False
        match_check = []
        match_col_id = []
        data_id = []
    return [W, A_rec, match_check, match_col_id, data_id, vals, exit_flag]

def sort_unmatched_columns(W, eps, d, c): 
    q = W.shape[1]
    col_id_new = -0.5*np.zeros(q)
    tau = (1-4*eps)*d
    matches = np.transpose(W)@W
    matches[matches<=tau] = 0
    matches[matches>tau] = 1
    i =0
    while i<q:
        if sum(matches[:,i]) > 0:
            temp = np.where(matches[:,i]==1)[0]
            col_id_new[temp] = c
            c +=1
            for j in range(len(temp)):
                matches[temp[j],:] = np.zeros(q)
                matches[:,temp[j]] = np.zeros(q)
        i +=1
    return [col_id_new, c]

def update_reconstruction(W, col_id, data_id, vals, A_rec, X_rec):
    for i in range(len(col_id)):
        A_rec[:, int(col_id[i])] += W[:,i]
        X_rec[int(col_id[i]), int(data_id[i])] = vals[i]
    A_rec[A_rec>0] = 1
    return [A_rec, X_rec]

def l0_decode(y, A, num_comp, alpha):
    tol = 10**-3
    tol2 = 10**-9
    converged = False
    r = copy.deepcopy(y)
    r_old = copy.deepcopy(y)
    x = np.zeros(num_comp)
    iters=1
    while converged == False and iters<10:
        vals = np.unique(r)
        vals = vals[vals!=0]
        for j in range(num_comp):
            r_0 = np.count_nonzero(r)
            for v in np.nditer(vals):
                u = r - v*A[:,j]
                u_0 = np.count_nonzero(u)
                if r_0 - u_0 >= alpha:
                    x[j] = x[j] + v
            r = y - A@x
            r[np.absolute(r)<tol2]=0
        if LA.norm(r - r_old) <= LA.norm(r_old)*tol or LA.norm(r)<=LA.norm(y)*tol:
            converged = True
        else:
            r_old = copy.deepcopy(r)
            iters +=1
        if iters == 10:
            print("Warning: max number of iterations of while loop in l0 decode step reached.")
            print('Percentage improvement in residual from penultimate iteration: ', str.format('{0:.5f}', LA.norm(r - r_old)))
            print('Size of final residual: ' ,  str.format('{0:.5f}', LA.norm(r)))
    return x

# %% [markdown]
# ### EBF Algorithm

# %%
def EBF(Y,N,m,n,d,k,eps,max_epochs,A_sparsity,X_sparsity,Y_frob):
    epoch = 0
    c = 0
    tol = 10**-8 # make sure is smaller than 1
    exit_program=False  
    A_rec = np.zeros((m,n))
    X_rec = np.zeros((n,N))
    frob_error_series = np.ones(max_epoch)
    A_entries = np.zeros(max_epoch)
    X_entries = np.zeros(max_epoch)
    total_entries = np.zeros(max_epoch)
    R = copy.deepcopy(Y)    
    start_time = timer()
    while epoch < max_epoch and frob_error_series[epoch] > tol and exit_program==False:            
        num_matched = 0
        num_new = 0    
        for i in range(N):
            [W, A_rec[:,:c], match_check, match_col_id, data_id, vals, supports_found]=process_column2(R[:,i], A_rec[:,:c], X_rec[:,i], m, eps, d, k, c, i)            
            if supports_found == True:
                matches = np.where(match_check==1)[0]
                new = np.where(match_check==0)[0]
                if len(matches)>0:
                    if num_matched > 0:
                        W_match = np.concatenate((W_match, W[:,matches]), axis=1)
                        col_id_match = np.concatenate((col_id_match, match_col_id[matches]), axis=0)
                        data_id_match = np.concatenate((data_id_match, data_id[matches]), axis=0)
                        val_match = np.concatenate((val_match, vals[matches]), axis=0)
                    else:
                        W_match = W[:,matches]
                        col_id_match = match_col_id[matches]
                        data_id_match = data_id[matches]
                        val_match = vals[matches]
                        num_matched += W_match.shape[1]

                if len(new)>0:
                    if num_new > 0:
                        W_new = np.concatenate((W_new, W[:,new]), axis=1)
                        data_id_new = np.concatenate((data_id_new, data_id[new]), axis=0)
                        val_new = np.concatenate((val_new, vals[new]), axis=0)
                    else:
                        W_new = W[:,new]
                        data_id_new = data_id[new]
                        val_new = vals[new]
                        num_new += W_new.shape[1]

        if num_matched > 0 and num_new > 0:
            [col_id_new, c] = sort_unmatched_columns(W_new, eps, d, c)       
            W_all = np.concatenate((W_match, W_new), axis=1)
            col_id_all = np.concatenate((col_id_match, col_id_new), axis=0)
            data_id_all = np.concatenate((data_id_match, data_id_new), axis=0)
            val_all = np.concatenate((val_match, val_new), axis=0)          
        elif num_matched > 0 and num_new == 0:
            W_all = W_match
            col_id_all = col_id_match
            data_id_all = data_id_match
            val_all = val_match     
        elif num_matched == 0 and num_new > 0:
            [col_id_all, c] = sort_unmatched_columns(W_new, eps, d, c)
            W_all = W_new
            data_id_all = data_id_new
            val_all = val_new                       
        elif num_matched == 0 and num_new == 0:
            print("No partial supports recovered, terminating algorithm")
            frob_error_series[epoch:] = frob_error_series[epoch-1]
            A_entries[epoch:] = A_entries[epoch-1]
            X_entries[epoch:] = X_entries[epoch-1]
            total_entries[epoch:] = total_entries[epoch-1]
            exit_program = True
        if exit_program == False:
            [A_rec, X_rec] = update_reconstruction(W_all, col_id_all, data_id_all, val_all, A_rec, X_rec)
            R = Y - A_rec@X_rec
            R[np.absolute(R)<tol] = 0
            frob_error_series[epoch] = np.sqrt(sum(sum(R**2)))
            A_entries[epoch] = np.count_nonzero(A_rec)
            X_entries[epoch] = np.count_nonzero(X_rec)
            total_entries[epoch] = A_entries[epoch] + X_entries[epoch]    
            print('Epoch ', str.format('{0:.0f}', epoch), " processed, l_2 error = ", str.format('{0:.2f}', 100*frob_error_series[epoch]/Y_frob), '%, A l_0 error =', str.format('{0:.2f}', 100*(A_sparsity - A_entries[epoch])/A_sparsity), '%, X l_0 error =', str.format('{0:.2f}', 100*(X_sparsity - X_entries[epoch])/X_sparsity), '%.')
            if epoch == max_epoch:
                print("Maximum number of epochs reached.")
            epoch +=1
    
    end_time = timer()
    comp_time = end_time - start_time
    return [A_rec, X_rec, frob_error_series, total_entries, A_entries, X_entries, comp_time]

# %%
def EBF_l0(Y,N,m,n,d,k,eps,max_epochs,A_sparsity,X_sparsity,Y_frob, alpha):
    epoch = 0
    c = 0
    tol = 10**-8 # make sure is smaller than 1
    exit_program=False  
    A_rec = np.zeros((m,n))
    X_rec = np.zeros((n,N))
    frob_error_series = np.ones(max_epoch)
    A_entries = np.zeros(max_epoch)
    X_entries = np.zeros(max_epoch)
    total_entries = np.zeros(max_epoch)
    R = copy.deepcopy(Y)    
    start_time = timer()
    while epoch < max_epoch and frob_error_series[epoch] > tol and exit_program==False:            
        num_matched = 0
        num_new = 0    
        for i in range(N):
            [W, A_rec[:,:c], match_check, match_col_id, data_id, vals, supports_found]=process_column2(R[:,i], A_rec[:,:c], X_rec[:,i], m, eps, d, k, c, i)
            if supports_found == True:
                matches = np.where(match_check==1)[0]
                new = np.where(match_check==0)[0]
                if len(matches)>0:
                    if num_matched > 0:
                        W_match = np.concatenate((W_match, W[:,matches]), axis=1)
                        col_id_match = np.concatenate((col_id_match, match_col_id[matches]), axis=0)
                        data_id_match = np.concatenate((data_id_match, data_id[matches]), axis=0)
                        val_match = np.concatenate((val_match, vals[matches]), axis=0)
                    else:
                        W_match = W[:,matches]
                        col_id_match = match_col_id[matches]
                        data_id_match = data_id[matches]
                        val_match = vals[matches]
                        num_matched += W_match.shape[1]

                if len(new)>0:
                    if num_new > 0:
                        W_new = np.concatenate((W_new, W[:,new]), axis=1)
                        data_id_new = np.concatenate((data_id_new, data_id[new]), axis=0)
                        val_new = np.concatenate((val_new, vals[new]), axis=0)
                    else:
                        W_new = W[:,new]
                        data_id_new = data_id[new]
                        val_new = vals[new]
                        num_new += W_new.shape[1]

        if num_matched > 0 and num_new > 0:
            [col_id_new, c] = sort_unmatched_columns(W_new, eps, d, c)       
            W_all = np.concatenate((W_match, W_new), axis=1)
            col_id_all = np.concatenate((col_id_match, col_id_new), axis=0)
            data_id_all = np.concatenate((data_id_match, data_id_new), axis=0)
            val_all = np.concatenate((val_match, val_new), axis=0)          
        elif num_matched > 0 and num_new == 0:
            W_all = W_match
            col_id_all = col_id_match
            data_id_all = data_id_match
            val_all = val_match     
        elif num_matched == 0 and num_new > 0:
            [col_id_all, c] = sort_unmatched_columns(W_new, eps, d, c)
            W_all = W_new
            data_id_all = data_id_new
            val_all = val_new                       
        elif num_matched == 0 and num_new == 0:
            print("No partial supports recovered, terminating algorithm")
            frob_error_series[epoch:] = frob_error_series[epoch-1]
            A_entries[epoch:] = A_entries[epoch-1]
            X_entries[epoch:] = X_entries[epoch-1]
            total_entries[epoch:] = total_entries[epoch-1]
            exit_program = True    
        
        if exit_program == False:
            [A_rec, X_rec] = update_reconstruction(W_all, col_id_all, data_id_all, val_all, A_rec, X_rec)  
          
            ### RUN l-0 HERE using completed columns ####            
            # Identify the completed columns of A at this iteration
            col_sumA = np.sum(A_rec, axis = 0)
            col_sumA[col_sumA != d] = 0
            comp = np.nonzero(col_sumA)[0]
            num_comp = len(comp)
            
            # Compute the residual based on the completed columns only
            R_l0 = Y - A_rec[:,comp]@X_rec[comp, :]
            R_l0[np.absolute(R_l0)<tol] = 0 
            # Identify which columns of the residual need to still try and decode
            col_sumR = np.sum(np.absolute(R_l0), axis = 0)
            col_sumR[np.absolute(col_sumR) < tol] = 0
            not_dec = np.nonzero(col_sumR)[0]
            num_2_process = len(not_dec)
            
            print("Running l0 decode on epoch ", str.format('{0:.0f}', epoch+1), ': n. of data points of Y still to decode = ', str.format('{0:.0f}', num_2_process), ", n. columns of A completed = ", str.format('{0:.0f}', num_comp),)       
            # Iterate through each column in turn and run l0 decode
            for j in range(num_2_process):
                X_l0_update = l0_decode(R_l0[:,not_dec[j]], A_rec[:,comp], num_comp, alpha)
                X_rec[comp, not_dec[j]] = X_rec[comp, not_dec[j]] + X_l0_update
                if np.mod(int(not_dec[j]),np.ceil(num_2_process/5)) == 0:
                    print("Processed ", str.format('{0:.0f}', j), " data points out of ", str.format('{0:.0f}', num_2_process))
            ############################################   
            
            R = Y - A_rec@X_rec
            R[np.absolute(R)<tol] = 0            
            frob_error_series[epoch] = np.sqrt(sum(sum(R**2)))
            A_entries[epoch] = np.count_nonzero(A_rec)
            X_entries[epoch] = np.count_nonzero(X_rec)
            total_entries[epoch] = A_entries[epoch] + X_entries[epoch]    
            print('Epoch ', str.format('{0:.0f}', epoch), " processed, l_2 error = ", str.format('{0:.2f}', 100*frob_error_series[epoch]/Y_frob), '%, A l_0 error =', str.format('{0:.2f}', 100*(A_sparsity - A_entries[epoch])/A_sparsity), '%, X l_0 error =', str.format('{0:.2f}', 100*(X_sparsity - X_entries[epoch])/X_sparsity), '%.')
            if epoch == max_epoch:
                print("Maximum number of epochs reached.")
            epoch +=1
    
    end_time = timer()
    comp_time = end_time - start_time
    return [A_rec, X_rec, frob_error_series, total_entries, A_entries, X_entries, comp_time]

# %% [markdown]
# # Analyzing performance of EBF while varying N

# %% [markdown]
# ## Generate synthetic data to run algorithms on

# %% [markdown]
# #### Generating a valid dictionary and data

# %%
# Dictionary parameters parameters
n = 1200
# beta = 900

m = 900
d = 10;
eps = 1/6;

N = [50, 100, 200, 400]
number_N_to_process = len(N)
maxN = 400

k = int(np.ceil(0.05*n))

# Generate a dictionary and check that passes necessary test.
num_generations = 0
passed = False
while passed==False and num_generations < 100:
    A = generate_exp_dictionary2(m,n,d);
    passed = check_dictionary(eps,n,d,A)
    num_generations += 1
if passed == True:
    print("Generated dictionary that passes the coherency test")
else:
    print("Failed to generate dictionary that passes the coherency test, consider different parameters")

A_sparsity = n*d
# Out:
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# A passes coherence test, mu_A =  3.00 , tau =  3.33 .
# Generated dictionary that passes the coherency test

# %% [markdown]
# #### Generate data

# %%
##### GENERATE LATENT REPRESENTATION for N1
b1=1;
b2=5;

X = np.zeros((n, maxN))
Y = np.zeros((m, maxN))
Y_frob = np.zeros(number_N_to_process)
X_sparsity = np.zeros(number_N_to_process)


for i in range(maxN):
    X[:,i] = generate_latent(n,k,b1,b2)
    
Y = A@X

for i in range(number_N_to_process):
    Y_frob[i] = np.sqrt(sum(sum(Y[:,:N[i]]**2)))
    X_sparsity[i] = k*N[i]

# %% [markdown]
# ## Check that l0 function is working as it should be

# %%
ind = 3
alpha=3
N_check = 1

Z = np.zeros((n, N_check))
offset = 28


for j in range(N_check):
    Z[:,j] = l0_decode(Y[:,offset+j], A, n, alpha)
    if np.mod(j,np.ceil(N_check/10)) == 0:
        print(j)
        
check_recon_X(X[:,offset:offset+N_check],Z,np.eye(n),N_check,k,n)
# Out:
# 0
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
# array([[ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        ...,
#        [ 0.        ],
#        [ 4.87109694],
#        [ 0.        ]])

# %% [markdown]
# ## Running EBF to recover A and X varying N

# %%
if passed == True:
    eps = 1/6;
    max_epoch = 8
    tol = 10**-8    
    comp_time = np.zeros(number_N_to_process)   
    A_rec = np.zeros((number_N_to_process,m,n))
    X_rec = []
    frob_error_series = np.ones((number_N_to_process, max_epoch))
    A_entries = np.zeros((number_N_to_process, max_epoch))
    X_entries = np.zeros((number_N_to_process, max_epoch))
    total_entries = np.zeros((number_N_to_process, max_epoch))
    for j in range(number_N_to_process):
        X_temp = np.zeros((n,N[j]))
        X_rec.append(X_temp)
        print("Solving problem with k/n = ", str.format('{0:.1f}', 100*k/n), '%, N = ', str.format('{0:.0f}', N[j]))       
        [A_rec[j], X_temp, frob_error_series[j], total_entries[j], A_entries[j], X_entries[j], comp_time[j]] = EBF(Y[:,:N[j]],N[j],m,n,d,k,eps,max_epoch,A_sparsity,X_sparsity[j],Y_frob[j])
        print("")
        P = check_recon_A(A, A_rec[j],d,eps,n)
        print("")
        check_recon_X(X[:,:N[j]],X_temp,P,N[j],k,n)
        print("")
# Out:
# Solving problem with k/n =  5.0 %, N =  50
# Epoch  0  processed, l_2 error =  89.46 %, A l_0 error = 64.53 %, X l_0 error = 76.73 %.
# Epoch  1  processed, l_2 error =  87.80 %, A l_0 error = 61.19 %, X l_0 error = 73.63 %.
# Epoch  2  processed, l_2 error =  87.16 %, A l_0 error = 59.83 %, X l_0 error = 72.63 %.
# Epoch  3  processed, l_2 error =  86.98 %, A l_0 error = 59.46 %, X l_0 error = 72.33 %.
# Epoch  4  processed, l_2 error =  86.89 %, A l_0 error = 59.32 %, X l_0 error = 72.20 %.
# Epoch  5  processed, l_2 error =  86.88 %, A l_0 error = 59.32 %, X l_0 error = 72.17 %.
# Epoch  6  processed, l_2 error =  86.85 %, A l_0 error = 59.25 %, X l_0 error = 72.10 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 8.6 % of columns fully formed.
# 41.8 % of columns partially formed.
# 49.7 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 59 % of entries missing in total.
# 1150 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 27.9 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 72.1 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  100
# Epoch  0  processed, l_2 error =  88.45 %, A l_0 error = 41.67 %, X l_0 error = 76.50 %.
# Epoch  1  processed, l_2 error =  85.08 %, A l_0 error = 33.95 %, X l_0 error = 70.95 %.
# Epoch  2  processed, l_2 error =  83.44 %, A l_0 error = 30.13 %, X l_0 error = 68.08 %.
# Epoch  3  processed, l_2 error =  82.28 %, A l_0 error = 28.26 %, X l_0 error = 66.38 %.
# Epoch  4  processed, l_2 error =  81.63 %, A l_0 error = 27.29 %, X l_0 error = 65.47 %.
# Epoch  5  processed, l_2 error =  81.24 %, A l_0 error = 26.53 %, X l_0 error = 64.85 %.
# Epoch  6  processed, l_2 error =  81.05 %, A l_0 error = 26.14 %, X l_0 error = 64.48 %.
# Epoch  7  processed, l_2 error =  80.90 %, A l_0 error = 25.77 %, X l_0 error = 64.22 %.
#
# Checking reconstruction of A.
# 37.1 % of columns fully formed.
# 46.9 % of columns partially formed.
# 16.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 26 % of entries missing in total.
# 1172 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 35.8 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 64.2 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  200
# Epoch  0  processed, l_2 error =  87.81 %, A l_0 error = 16.69 %, X l_0 error = 76.49 %.
# Epoch  1  processed, l_2 error =  82.84 %, A l_0 error = 9.03 %, X l_0 error = 68.42 %.
# Epoch  2  processed, l_2 error =  79.36 %, A l_0 error = 5.47 %, X l_0 error = 63.12 %.
# Epoch  3  processed, l_2 error =  76.49 %, A l_0 error = 3.52 %, X l_0 error = 58.88 %.
# Epoch  4  processed, l_2 error =  74.05 %, A l_0 error = 2.42 %, X l_0 error = 55.14 %.
# Epoch  5  processed, l_2 error =  71.73 %, A l_0 error = 1.77 %, X l_0 error = 51.62 %.
# Epoch  6  processed, l_2 error =  69.38 %, A l_0 error = 1.23 %, X l_0 error = 48.28 %.
# Epoch  7  processed, l_2 error =  67.13 %, A l_0 error = 0.77 %, X l_0 error = 45.27 %.
#
# Checking reconstruction of A.
# 94.5 % of columns fully formed.
# 5.5 % of columns partially formed.
# 0.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 1 % of entries missing in total.
# 92 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 54.7 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 45.3 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  400
# Epoch  0  processed, l_2 error =  87.57 %, A l_0 error = 3.05 %, X l_0 error = 76.64 %.
# Epoch  1  processed, l_2 error =  81.70 %, A l_0 error = 0.68 %, X l_0 error = 67.09 %.
# Epoch  2  processed, l_2 error =  77.72 %, A l_0 error = 0.22 %, X l_0 error = 60.71 %.
# Epoch  3  processed, l_2 error =  74.41 %, A l_0 error = 0.07 %, X l_0 error = 55.62 %.
# Epoch  4  processed, l_2 error =  71.38 %, A l_0 error = 0.04 %, X l_0 error = 51.22 %.
# Epoch  5  processed, l_2 error =  68.59 %, A l_0 error = 0.01 %, X l_0 error = 47.30 %.
# Epoch  6  processed, l_2 error =  66.05 %, A l_0 error = 0.01 %, X l_0 error = 43.89 %.
# Epoch  7  processed, l_2 error =  63.82 %, A l_0 error = 0.01 %, X l_0 error = 40.93 %.
#
# Checking reconstruction of A.
# 99.9 % of columns fully formed.
# 0.1 % of columns partially formed.
# 0.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 0 % of entries missing in total.
# 1 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 59.1 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 40.9 % of entries missing.

# %%
plt.figure(1).clear()

plot_A_entries = 100*A_entries/A_sparsity

plot_X_entries = np.zeros((number_N_to_process, max_epoch))
plot_frob = np.zeros((number_N_to_process, max_epoch))

for j in range(number_N_to_process):
    plot_X_entries[j,:] = 100*X_entries[j,:]/X_sparsity[j]
plot_epoch = max_epoch 

plt.figure(1)
plt.figure(figsize=(15,20))
plt.subplot(2,2,1)
plt.plot(np.arange(max_epoch)+1, plot_A_entries[0], 'c-', label="A, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[1], 'm-', label="A, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[2], 'r-', label="A, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[3], 'y-', label="A, N=%s"%(N[3]))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBF varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of A recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.subplot(2,2,2)
plt.plot(np.arange(max_epoch)+1, plot_X_entries[0], 'c-',label="X, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[1], 'm-',label="X, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[2], 'r-',label="X, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[3], 'y-',label="X, N=%s"%(N[3]))
plt.grid(True)
plt.title('Percentage of entries of X recovered by EBF varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of X recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
# plt.savefig('./figures_ACHA/EBF_performance.eps', format='eps', bbox_inches='tight')

# %% [markdown]
# ## Running l0-EBF to recover A and X varying $N$

# %%
# Extra parameters required for l0-EBF
alpha=3

if passed == True:
    eps = 1/6;
    max_epoch = 8
    tol = 10**-8    
    comp_time_l0 = np.zeros(number_N_to_process)   
    A_rec_l0 = np.zeros((number_N_to_process,m,n))
    X_rec_l0 = []
    frob_error_series_l0 = np.ones((number_N_to_process, max_epoch))
    A_entries_l0 = np.zeros((number_N_to_process, max_epoch))
    X_entries_l0 = np.zeros((number_N_to_process, max_epoch))
    total_entries_l0 = np.zeros((number_N_to_process, max_epoch))
    for j in range(number_N_to_process):
        X_temp = np.zeros((n,N[j]))
        print("Solving problem with k/n = ", str.format('{0:.1f}', 100*k/n), '%, N = ', str.format('{0:.0f}', N[j]))       
        [A_rec_l0[j], X_temp, frob_error_series_l0[j], total_entries_l0[j], A_entries_l0[j], X_entries_l0[j], comp_time_l0[j]] = EBF_l0(Y[:,:N[j]],N[j],m,n,d,k,eps,max_epoch,A_sparsity,X_sparsity[j],Y_frob[j],alpha)
        print("")
        P = check_recon_A(A, A_rec[j],d,eps,n)
        print("")
        check_recon_X(X[:,:N[j]],X_temp,P,N[j],k,n)
        print("")
        X_rec.append(X_temp)
# Out:
# Solving problem with k/n =  5.0 %, N =  50
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  50 , n. columns of A completed =  74
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  0  processed, l_2 error =  86.84 %, A l_0 error = 64.53 %, X l_0 error = 72.27 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  50 , n. columns of A completed =  115
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  1  processed, l_2 error =  81.85 %, A l_0 error = 56.83 %, X l_0 error = 63.27 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  50 , n. columns of A completed =  149
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  2  processed, l_2 error =  78.10 %, A l_0 error = 51.52 %, X l_0 error = 57.33 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  50 , n. columns of A completed =  173
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  3  processed, l_2 error =  75.65 %, A l_0 error = 48.17 %, X l_0 error = 53.20 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  50 , n. columns of A completed =  189
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  4  processed, l_2 error =  73.90 %, A l_0 error = 45.45 %, X l_0 error = 50.00 %.
# Running l0 decode on epoch  6 : n. of data points of Y still to decode =  50 , n. columns of A completed =  208
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  5  processed, l_2 error =  72.21 %, A l_0 error = 43.49 %, X l_0 error = 47.40 %.
# Running l0 decode on epoch  7 : n. of data points of Y still to decode =  50 , n. columns of A completed =  227
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  6  processed, l_2 error =  70.27 %, A l_0 error = 41.56 %, X l_0 error = 44.70 %.
# Running l0 decode on epoch  8 : n. of data points of Y still to decode =  50 , n. columns of A completed =  260
# Processed  0  data points out of  50
# Processed  10  data points out of  50
# Processed  20  data points out of  50
# Processed  30  data points out of  50
# Processed  40  data points out of  50
# Epoch  7  processed, l_2 error =  67.64 %, A l_0 error = 39.22 %, X l_0 error = 41.10 %.
#
# Checking reconstruction of A.
# 8.6 % of columns fully formed.
# 41.8 % of columns partially formed.
# 49.7 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 59 % of entries missing in total.
# 1150 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# Column number =  0 , row number =  1097 , true value =  -3.43988839401 value found =  -3.09330452353
# Column number =  12 , row number =  989 , true value =  -3.78921993904 value found =  -1.62045605425
# Column number =  18 , row number =  64 , true value =  1.21509494131 value found =  -1.01091397446
# Column number =  18 , row number =  1105 , true value =  2.64671715095 value found =  3.4014344651
# Column number =  19 , row number =  524 , true value =  -4.60878288931 value found =  3.40551353991
# Column number =  19 , row number =  1155 , true value =  4.98937621062 value found =  3.39400504149
# Column number =  37 , row number =  441 , true value =  -4.03799181802 value found =  -2.31920105939
# 43.6 % of entries correctly recovered.
# 0.2 % of entries in correct location but have wrong value for location.
# 56.1 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  100
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  100 , n. columns of A completed =  223
# Processed  0  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  63.54487
# Processed  20  data points out of  100
# Processed  40  data points out of  100
# Processed  60  data points out of  100
# Processed  80  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  64.22345
# Epoch  0  processed, l_2 error =  80.33 %, A l_0 error = 41.67 %, X l_0 error = 62.63 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  100 , n. columns of A completed =  545
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  60.51504
# Processed  0  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  43.49411
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  55.10183
# Processed  20  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  52.91626
# Processed  40  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  48.82382
# Processed  60  data points out of  100
# Processed  80  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  43.25354
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  53.53566
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  50.82950
# Epoch  1  processed, l_2 error =  58.40 %, A l_0 error = 19.57 %, X l_0 error = 31.78 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  100 , n. columns of A completed =  975
# Processed  0  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.11378
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  46.90019
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.84194
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  32.23144
# Processed  20  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  27.58539
# Processed  40  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.76426
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.41529
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.44994
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  27.45731
# Processed  60  data points out of  100
# Processed  80  data points out of  100
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.25551
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.51915
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.17353
# Epoch  2  processed, l_2 error =  24.09 %, A l_0 error = 4.46 %, X l_0 error = 4.55 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  55 , n. columns of A completed =  1165
# Processed  0  data points out of  55
# Processed  10  data points out of  55
# Processed  16  data points out of  55
# Processed  23  data points out of  55
# Processed  34  data points out of  55
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.91034
# Processed  54  data points out of  55
# Epoch  3  processed, l_2 error =  4.53 %, A l_0 error = 0.63 %, X l_0 error = 0.02 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  18 , n. columns of A completed =  1182
# Processed  0  data points out of  18
# Processed  3  data points out of  18
# Processed  16  data points out of  18
# Epoch  4  processed, l_2 error =  2.26 %, A l_0 error = 0.47 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 37.1 % of columns fully formed.
# 46.9 % of columns partially formed.
# 16.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 26 % of entries missing in total.
# 1172 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# Column number =  1 , row number =  906 , true value =  1.15942297385 value found =  1.4408104176
# Column number =  3 , row number =  355 , true value =  -4.64959606194 value found =  1.70345487669
# Column number =  11 , row number =  721 , true value =  1.80356420535 value found =  -3.76304391438
# Column number =  13 , row number =  68 , true value =  -2.33481266078 value found =  3.60431617135
# Column number =  13 , row number =  144 , true value =  4.58555784559 value found =  3.38648015675
# Column number =  13 , row number =  1185 , true value =  3.60431617135 value found =  4.92836901616
# Column number =  17 , row number =  64 , true value =  -4.23393723136 value found =  -1.44658300476
# Column number =  21 , row number =  605 , true value =  1.16802200958 value found =  -3.59805358226
# Column number =  26 , row number =  689 , true value =  -4.47441477027 value found =  4.37710103532
# Column number =  28 , row number =  195 , true value =  4.60126413685 value found =  -4.03021738744
# Column number =  29 , row number =  288 , true value =  1.85663392324 value found =  2.61152009184
# Column number =  39 , row number =  85 , true value =  -3.08083549132 value found =  4.98285347906
# Column number =  44 , row number =  316 , true value =  4.05037513257 value found =  -3.00685716784
# Column number =  50 , row number =  571 , true value =  3.05070864259 value found =  1.54869047794
# Column number =  52 , row number =  760 , true value =  -2.8074547848 value found =  -2.27441650461
# Column number =  61 , row number =  748 , true value =  4.41367302042 value found =  -2.74970914941
# Column number =  62 , row number =  705 , true value =  3.18546669289 value found =  4.01382789947
# Column number =  63 , row number =  338 , true value =  -1.10693304676 value found =  -2.04363925694
# Column number =  67 , row number =  526 , true value =  -1.02187072853 value found =  -1.83935392082
# Column number =  70 , row number =  1065 , true value =  2.49119706058 value found =  -2.14156621368
# Column number =  70 , row number =  1105 , true value =  -2.96864533993 value found =  -4.4268376582
# Column number =  74 , row number =  932 , true value =  4.36832207965 value found =  3.05393164478
# Column number =  76 , row number =  58 , true value =  4.25870768028 value found =  -3.86591520577
# Column number =  78 , row number =  1072 , true value =  4.59210144197 value found =  1.25304165751
# Column number =  79 , row number =  159 , true value =  -3.98210798383 value found =  -2.63932073987
# Column number =  79 , row number =  1091 , true value =  -1.12457843873 value found =  1.68637128577
# Column number =  84 , row number =  902 , true value =  4.6980361229 value found =  -3.19521207158
# Column number =  86 , row number =  1185 , true value =  3.19162649618 value found =  -1.29584873832
# Column number =  93 , row number =  1131 , true value =  -4.46805502187 value found =  4.55546549034
# Column number =  99 , row number =  357 , true value =  -1.13624393024 value found =  1.39373070838
# 76.5 % of entries correctly recovered.
# 0.5 % of entries in correct location but have wrong value for location.
# 23.0 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  200
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  200 , n. columns of A completed =  610
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  60.36672
# Processed  0  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  60.63726
# Processed  40  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  44.67677
# Processed  80  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  49.59635
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  47.38365
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  47.79596
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  49.43603
# Processed  120  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  60.79368
# Processed  160  data points out of  200
# Epoch  0  processed, l_2 error =  62.25 %, A l_0 error = 16.69 %, X l_0 error = 38.08 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  195 , n. columns of A completed =  1188
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.11288
# Processed  0  data points out of  195
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.51825
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.93910
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.98793
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.84467
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.82536
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.32725
# Processed  38  data points out of  195
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  4.87918
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.58086
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.55632
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.90822
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.54006
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.84730
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.42549
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.74154
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.58281
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.25807
# Processed  77  data points out of  195
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.00389
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.43881
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.60075
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.37995
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.31201
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.27951
# Processed  115  data points out of  195
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.63896
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.04373
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  3.49277
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.77993
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  5.27582
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.95118
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.57757
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.44032
# Processed  153  data points out of  195
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.89007
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.05534
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.37194
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.06310
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.84497
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.69674
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.23540
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.43325
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.03225
# Processed  190  data points out of  195
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.27299
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.37354
# Epoch  1  processed, l_2 error =  8.22 %, A l_0 error = 0.10 %, X l_0 error = 0.24 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  42 , n. columns of A completed =  1200
# Processed  0  data points out of  42
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.75836
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.11263
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.00778
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.55987
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.55164
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.33615
# Processed  36  data points out of  42
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.99098
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.54597
# Processed  40  data points out of  42
# Epoch  2  processed, l_2 error =  5.90 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  8 , n. columns of A completed =  1200
# Processed  0  data points out of  8
# Processed  2  data points out of  8
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  36.15988
# Processed  4  data points out of  8
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  45.50423
# Processed  5  data points out of  8
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.73873
# Processed  6  data points out of  8
# Processed  7  data points out of  8
# Epoch  3  processed, l_2 error =  5.81 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  3 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  48.21318
# Processed  0  data points out of  3
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  60.67230
# Processed  1  data points out of  3
# Processed  2  data points out of  3
# Epoch  4  processed, l_2 error =  6.94 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  6 : n. of data points of Y still to decode =  2 , n. columns of A completed =  1200
# Processed  0  data points out of  2
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  75.84038
# Processed  1  data points out of  2
# Epoch  5  processed, l_2 error =  6.80 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  7 : n. of data points of Y still to decode =  1 , n. columns of A completed =  1200
# Processed  0  data points out of  1
# Epoch  6  processed, l_2 error =  0.00 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 94.5 % of columns fully formed.
# 5.5 % of columns partially formed.
# 0.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 1 % of entries missing in total.
# 92 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# Column number =  11 , row number =  488 , true value =  1.48616370855 value found =  2.27184127248
# Column number =  13 , row number =  325 , true value =  4.20971885508 value found =  -2.06476923175
# Column number =  13 , row number =  860 , true value =  3.9607664564 value found =  -2.88128779768
# Column number =  25 , row number =  599 , true value =  3.86668554731 value found =  1.68507192113
# Column number =  48 , row number =  1101 , true value =  -1.68346867186 value found =  -3.05931401737
# Column number =  51 , row number =  692 , true value =  -3.39170961942 value found =  1.10792646707
# Column number =  54 , row number =  37 , true value =  3.97408853257 value found =  1.99810697416
# Column number =  60 , row number =  116 , true value =  -1.20388267354 value found =  1.41173993938
# Column number =  65 , row number =  387 , true value =  4.45424291784 value found =  3.04026751852
# Column number =  97 , row number =  319 , true value =  -1.9580617357 value found =  -2.35725582564
# Column number =  107 , row number =  805 , true value =  -4.1830081109 value found =  2.88344344534
# Column number =  113 , row number =  1114 , true value =  -1.29165296071 value found =  -3.83691843835
# Column number =  114 , row number =  671 , true value =  1.52694618139 value found =  3.27466680849
# Column number =  125 , row number =  488 , true value =  -4.79312331909 value found =  -2.64898679074
# Column number =  131 , row number =  495 , true value =  1.25814707751 value found =  -1.10469853374
# Column number =  131 , row number =  816 , true value =  -1.66043620873 value found =  -1.24761917068
# Column number =  138 , row number =  1091 , true value =  1.16963807136 value found =  -2.44960746396
# Column number =  160 , row number =  941 , true value =  3.2652124202 value found =  3.88293390804
# Column number =  167 , row number =  460 , true value =  -1.87378748048 value found =  -1.05181137672
# Column number =  167 , row number =  739 , true value =  -1.99757784201 value found =  -1.87378748048
# Column number =  168 , row number =  1117 , true value =  3.53182127121 value found =  -3.23792981631
# Column number =  171 , row number =  1105 , true value =  1.56552268807 value found =  2.93196161684
# Column number =  182 , row number =  76 , true value =  4.57451651255 value found =  2.18682324642
# Column number =  187 , row number =  941 , true value =  1.45445411519 value found =  -1.71218954225
# Column number =  191 , row number =  58 , true value =  -2.53944442034 value found =  2.7993090095
# Column number =  191 , row number =  389 , true value =  -4.6268242504 value found =  -2.35868838526
# Column number =  191 , row number =  941 , true value =  2.7993090095 value found =  2.20426292395
# 92.9 % of entries correctly recovered.
# 0.2 % of entries in correct location but have wrong value for location.
# 6.9 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  400
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  400 , n. columns of A completed =  1031
# Processed  0  data points out of  400
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  38.48001
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  35.82609
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.07353
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.34329
# Processed  80  data points out of  400
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.54056
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.00881
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.69898
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.24002
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.93379
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  38.44907
# Processed  160  data points out of  400
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  32.82921
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.38237
# Processed  240  data points out of  400
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.66569
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.06490
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.28221
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  32.46856
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.26089
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.61164
# Processed  320  data points out of  400
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.75542
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.79144
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.94409
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.65406
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.34418
# Epoch  0  processed, l_2 error =  33.33 %, A l_0 error = 3.05 %, X l_0 error = 10.68 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  38 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.84467
# Processed  2  data points out of  38
# Processed  4  data points out of  38
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.60075
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.81033
# Processed  15  data points out of  38
# Processed  20  data points out of  38
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.04179
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.70835
# Processed  26  data points out of  38
# Processed  29  data points out of  38
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  4.04065
# Processed  32  data points out of  38
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  3.44590
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.52339
# Processed  35  data points out of  38
# Epoch  1  processed, l_2 error =  2.75 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  8 , n. columns of A completed =  1200
# Processed  0  data points out of  8
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  37.56268
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  37.06253
# Processed  4  data points out of  8
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.08130
# Processed  5  data points out of  8
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.89181
# Processed  6  data points out of  8
# Processed  7  data points out of  8
# Epoch  2  processed, l_2 error =  3.42 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  4 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  50.08357
# Processed  0  data points out of  4
# Processed  1  data points out of  4
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.12195
# Processed  2  data points out of  4
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.33771
# Processed  3  data points out of  4
# Epoch  3  processed, l_2 error =  3.34 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  3 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  62.60447
# Processed  0  data points out of  3
# Processed  1  data points out of  3
# Processed  2  data points out of  3
# Epoch  4  processed, l_2 error =  3.98 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  6 : n. of data points of Y still to decode =  1 , n. columns of A completed =  1200
# Processed  0  data points out of  1
# Epoch  5  processed, l_2 error =  0.00 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 99.9 % of columns fully formed.
# 0.1 % of columns partially formed.
# 0.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 0 % of entries missing in total.
# 1 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# Column number =  27 , row number =  1116 , true value =  1.1376414805 value found =  -1.91924262952
# Column number =  54 , row number =  526 , true value =  -2.90488014055 value found =  4.93667891265
# Column number =  74 , row number =  1058 , true value =  2.02329517652 value found =  3.78437032264
# Column number =  92 , row number =  1173 , true value =  -4.22401838278 value found =  -2.72875183311
# Column number =  152 , row number =  46 , true value =  -1.04730464482 value found =  -1.5762478218
# Column number =  152 , row number =  76 , true value =  -1.5762478218 value found =  2.78034033272
# Column number =  152 , row number =  526 , true value =  1.17264883368 value found =  -1.04730464482
# Column number =  198 , row number =  860 , true value =  2.62972872399 value found =  1.7155105773
# Column number =  367 , row number =  1058 , true value =  -1.34495194526 value found =  3.99645970381
# 99.2 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.8 % of entries missing.

# %%
plt.figure(2).clear()

plot_A_entries_l0 = 100*A_entries_l0/A_sparsity

plot_X_entries_l0 = np.zeros((number_N_to_process, max_epoch))
plot_frob_l0 = np.zeros((number_N_to_process, max_epoch))

for j in range(number_N_to_process):
    plot_X_entries_l0[j,:] = 100*X_entries_l0[j,:]/X_sparsity[j]
plot_epoch = max_epoch 

plt.figure(2)
plt.figure(figsize=(15,20))
plt.subplot(2,2,1)
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[0], 'c--', label="A, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[1], 'm--', label="A, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[2], 'r--', label="A, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[3], 'y--', label="A, N=%s"%(N[3]))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBF-l0 varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of A recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.subplot(2,2,2)
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[0], 'c--',label="X, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[1], 'm--',label="X, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[2], 'r--',label="X, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[3], 'y--',label="X, N=%s"%(N[3]))
plt.grid(True)
plt.title('Percentage of entries of X recovered by EBF-l0 varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of X recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
# plt.savefig('./figures_ACHA/EBF_performance.eps', format='eps', bbox_inches='tight')

# %% [markdown]
# ## Side by side comparison of EBF vs l0-EBF

# %%
plot_epoch = 6
plt.figure(3)
plt.figure(figsize=(15,20))
plt.subplot(2,2,1)
# plt.plot(np.arange(max_epoch)+1, plot_A_entries[0], 'c-', label="EBF, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[1], 'b-', label="EBF, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[2], 'r-', label="EBF, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[3], 'g-', label="EBF, N=%s"%(N[3]))
# plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[0], 'c--', label="${\ell_0}$-EBF, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[1], 'b--', label="${\ell_0}$-EBF, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[2], 'r--', label="${\ell_0}$-EBF, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[3], 'g--', label="${\ell_0}$-EBF, N=%s"%(N[3]))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBF and ${\ell_0}$-EBF varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of A recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.subplot(2,2,2)
# plt.plot(np.arange(max_epoch)+1, plot_X_entries[0], 'c-',label="EB, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[1], 'b-',label="EBF, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[2], 'r-',label="EBF, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[3], 'g-',label="EBF, N=%s"%(N[3]))
# plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[0], 'c--',label="${\ell_0}$-EBF, N=%s"%(N[0]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[1], 'b--',label="${\ell_0}$-EBF, N=%s"%(N[1]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[2], 'r--',label="${\ell_0}$-EBF, N=%s"%(N[2]))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[3], 'g--',label="${\ell_0}$-EBF, N=%s"%(N[3]))
plt.grid(True)
plt.title('Percentage of entries of X recovered by EBF and ${\ell_0}$-EBF varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of X recovered (%)')
plt.xlim(1,plot_epoch)
# plt.legend()
plt.savefig('./figures_ACHA/EBF_vs_EBF_l0_comparison_N.eps', format='eps', bbox_inches='tight')

# %%
np.count_nonzero(np.sum(X[0:100],1))
# Out:
# 100
