# %% [markdown]
# # Matrix Factorization with Expander Graphs

# %% [markdown]
# ## Supporting Functions
#
# ### Functions for generating and checking data

# %%
# IMPORTS
import numpy as np
import copy
import matplotlib.pyplot as plt
from timeit import default_timer as timer
from numpy import linalg as LA


# DATA GENERATION AND PERFORMANCE CHECKING FUNCTIONS
def generate_latent(n,k,c1,c2):
    b = c2-c1
    a = c1/b
    x = np.zeros(n)
    locs = np.random.permutation(n)[:k]
    x[locs] = 1
    signs = np.sign(np.random.randn(k))
    vals = b*(np.random.rand(k)+a)
    x[locs] = x[locs]*vals*signs
    return x

def generate_exp_dictionary1(m,n,d):
    A = np.zeros((m,n))
    for i in range(n):
        locs = np.random.permutation(m)[:d]
        A[locs,i] = 1
    return A

def generate_exp_dictionary2(m,n,d):
    A = np.zeros((m,n))
    alpha = int(np.floor(m/d))
    c = 0
    while c<n:
        perm = np.random.permutation(m)
        zeta = min(n-c, alpha)
        for j in range(zeta):
            locs = perm[j*d:(j+1)*d]
            A[locs,c] = 1
            c = c+1
    return A

def check_dictionary(eps,n,d,A):
    t = (1-4*eps)*d
    mu_A = np.max(np.transpose(A)@A - d*np.identity(n))
    if mu_A >= t:
        print("Generation error, A is not expander for this value of epsilon, mu_A = ", str.format('{0:.2f}', mu_A),", tau = ", str.format('{0:.2f}', t), ".")
        passed = False
    else:
        print("A passes coherence test, mu_A = ", str.format('{0:.2f}', mu_A),", tau = ", str.format('{0:.2f}', t), ".")
        passed = True
    return passed  
        
def check_recon_A(A,A_rec,d,eps,n):
    print("Checking reconstruction of A.")
    col_sum = sum(A_rec)
    print(str.format('{0:.1f}',100*len(col_sum[col_sum==d])/n), "% of columns fully formed.")
    print(str.format('{0:.1f}',100*(n - len(col_sum[col_sum==d]) - len(col_sum[col_sum==0]))/n) , "% of columns partially formed.")
    print(str.format('{0:.1f}', 100*len(col_sum[col_sum==0])/n), "% of columns have no entries.")
    overlaps = np.transpose(A_rec)@A
    A_rec_col, A_col = np.where(overlaps>(1-4*eps)*d)
    if len(col_sum[col_sum==0])<n:
        print(str.format('{0:.1f}', 100*len(A_rec_col)/(n - len(col_sum[col_sum==0]))), "% of reconstructed (fully or partially) columns match with a column in target matrix.")  
    error = 0
    missing = 0
    P = np.zeros((n,n))
    for i in range(len(A_rec_col)):
        diff = A_rec[:, A_rec_col[i]] - A[:,A_col[i]]
        error = error + sum(abs(diff[diff==1]))
        missing = missing + sum(abs(diff[diff==-1]))
        P[A_col[i], A_rec_col[i]] = 1
    print(str.format('{0:.0f}', 100*(missing+d*n-len(A_rec_col)*d)/(d*n)), "% of entries missing in total.")
    print(str.format('{0:.0f}', missing), "entries missing in matched columns.")
    print(str.format('{0:.0f}', error), "entries wrong in matched columns.")
    return P
    
def check_recon_X(X,X_rec,P,N,k,n):
    X_perm = P@X_rec
    print("Checking the values of X recovered.")
    tol = 10**-6
    total_entries = N*k
    total_entries_recovered = 0
    correct_loc_correct_val = 0
    correct_loc_wrong_val = 0
    wrong_loc = 0
    missing = 0
    passed = True
    for i in range(N):
        for j in range(n):
            if abs(X[j,i])>tol and abs(X_perm[j,i])>tol:
                error = abs(X[j,i] - X_perm[j,i])
                if error < tol:
                    correct_loc_correct_val +=1
                else:
                    correct_loc_wrong_val += 1
                    print("Column number = ", i, ", row number = ", j, ", true value = ", X[j,i], "value found = ", X_perm[j,i])
            elif abs(X[j,i])>tol and abs(X_perm[j,i])<tol:
                missing += 1
            elif abs(X[j,i])<tol and abs(X_perm[j,i])>tol:
                wrong_loc += 1
    print(str.format('{0:.1f}', 100*(correct_loc_correct_val/total_entries)), "% of entries correctly recovered.")
    print(str.format('{0:.1f}', 100*(correct_loc_wrong_val/total_entries)), "% of entries in correct location but have wrong value for location.")
    print(str.format('{0:.1f}', 100*(missing/total_entries)), "% of entries missing.")
    return X_perm

# %% [markdown]
# ### Auxillary functions

# %%
# USED IN BOTH EXPERIMENTS 1 and 2
def xps2(y,x_vals,x_locs,A_rec,m,eps,d,k):
    tol1 = 10**-8
    tol2 = 10**-8
    y_copy = copy.deepcopy(y)
    t = (1-2*eps)*d
    z1 = len(y_copy);
    W = np.zeros((m,k))
    vals = np.zeros(k)
    q = 0
    for i in range(z1):
        if np.abs(y_copy[i])> tol1:
            locs = list()
            locs.append(i)
            for j in range(i+1, m):
                if np.abs(y_copy[j] - y_copy[i]) < tol2:
                    locs.append(j)
                    y_copy[j] = 0
            match = np.where(y_copy[i]==x_vals)[0]
            if not match:
                if len(locs)>t:
                    W[locs,q] = 1
                    vals[q] = y_copy[i]
                    q = q+1
            elif len(match)==1:
                A_rec[locs, x_locs[match[0]]] = 1
            else:
                print('ERROR - column value matches with more than 1 singleton value already extracted')
        y_copy[i] = 0
    W = W[:,:q]
    vals = vals[:q]
    return [W, A_rec, vals, q]

def process_column2(y, A_rec, x, m, eps, d, k, c, dpid):
    exit_flag = True
    tau = (1-4*eps)*d
    x_locs = np.nonzero(x)[0]
    x_vals = np.zeros(len(x_locs))
    for i in range(len(x_locs)):
        x_vals[i] = x[x_locs[i]]  
    [W, A_rec, vals, q] = xps2(y,x_vals,x_locs,A_rec,m,eps,d,k)
    if q > 0:
        match_check = np.zeros(q) 
        match_col_id = -0.5*np.ones(q)
        data_id = dpid*np.ones(q)          
        if c > 0:           
            matches = np.transpose(W)@A_rec
            matches[matches<=tau] = 0
            matches[matches>tau] = 1
            num_matches = matches.sum(axis=1)
            col_ind = matches@np.arange(c)           
            for i in range(q):
                if num_matches[i] == 0:
                    if c>=n:
                        print("Error: trying to add new column which exceeds total number of columns")
                        exit_flag==False
                elif num_matches[i] == 1:
                    match_check[i] = 1                   
                    z = int(col_ind[i])
                    match_col_id[i] = z
                elif num_matches[i] > 1:
                    print("Error: partial support matches with ", num_matches[i]," partially reconstructed columns of A.")
                    exit_flag = False
    else:
        exit_flag = False
        match_check = []
        match_col_id = []
        data_id = []
    return [W, A_rec, match_check, match_col_id, data_id, vals, exit_flag]

def sort_unmatched_columns(W, eps, d, c): 
    q = W.shape[1]
    col_id_new = -0.5*np.zeros(q)
    tau = (1-4*eps)*d
    matches = np.transpose(W)@W
    matches[matches<=tau] = 0
    matches[matches>tau] = 1
    i =0
    while i<q:
        if sum(matches[:,i]) > 0:
            temp = np.where(matches[:,i]==1)[0]
            col_id_new[temp] = c
            c +=1
            for j in range(len(temp)):
                matches[temp[j],:] = np.zeros(q)
                matches[:,temp[j]] = np.zeros(q)
        i +=1
    return [col_id_new, c]

def update_reconstruction(W, col_id, data_id, vals, A_rec, X_rec):
    for i in range(len(col_id)):
        A_rec[:, int(col_id[i])] += W[:,i]
        X_rec[int(col_id[i]), int(data_id[i])] = vals[i]
    A_rec[A_rec>0] = 1
    return [A_rec, X_rec]

def l0_decode(y, A, num_comp, alpha):
    tol = 10**-3
    tol2 = 10**-9
    converged = False
    r = copy.deepcopy(y)
    r_old = copy.deepcopy(y)
    x = np.zeros(num_comp)
    iters=1
    while converged == False and iters<10:
        vals = np.unique(r)
        vals = vals[vals!=0]
        for j in range(num_comp):
            r_0 = np.count_nonzero(r)
            for v in np.nditer(vals):
                u = r - v*A[:,j]
                u_0 = np.count_nonzero(u)
                if r_0 - u_0 >= alpha:
                    x[j] = x[j] + v
            r = y - A@x
            r[np.absolute(r)<tol2]=0
        if LA.norm(r - r_old) <= LA.norm(r_old)*tol or LA.norm(r)<=LA.norm(y)*tol:
            converged = True
        else:
            r_old = copy.deepcopy(r)
            iters +=1
        if iters == 10:
            print("Warning: max number of iterations of while loop in l0 decode step reached.")
            print('Percentage improvement in residual from penultimate iteration: ', str.format('{0:.5f}', LA.norm(r - r_old)))
            print('Size of final residual: ' ,  str.format('{0:.5f}', LA.norm(r)))
    return x

# %% [markdown]
# ### EBR Algorithm

# %%
def EBR(Y,N,m,n,d,k,eps,max_epochs,A_sparsity,X_sparsity,Y_frob):
    epoch = 0
    c = 0
    tol = 10**-8 # make sure is smaller than 1
    exit_program=False  
    A_rec = np.zeros((m,n))
    X_rec = np.zeros((n,N))
    frob_error_series = np.ones(max_epoch)
    A_entries = np.zeros(max_epoch)
    X_entries = np.zeros(max_epoch)
    total_entries = np.zeros(max_epoch)
    R = copy.deepcopy(Y)    
    start_time = timer()
    while epoch < max_epoch and frob_error_series[epoch] > tol and exit_program==False:            
        num_matched = 0
        num_new = 0    
        for i in range(N):
            [W, A_rec[:,:c], match_check, match_col_id, data_id, vals, supports_found]=process_column2(R[:,i], A_rec[:,:c], X_rec[:,i], m, eps, d, k, c, i)            
            if supports_found == True:
                matches = np.where(match_check==1)[0]
                new = np.where(match_check==0)[0]
                if len(matches)>0:
                    if num_matched > 0:
                        W_match = np.concatenate((W_match, W[:,matches]), axis=1)
                        col_id_match = np.concatenate((col_id_match, match_col_id[matches]), axis=0)
                        data_id_match = np.concatenate((data_id_match, data_id[matches]), axis=0)
                        val_match = np.concatenate((val_match, vals[matches]), axis=0)
                    else:
                        W_match = W[:,matches]
                        col_id_match = match_col_id[matches]
                        data_id_match = data_id[matches]
                        val_match = vals[matches]
                        num_matched += W_match.shape[1]

                if len(new)>0:
                    if num_new > 0:
                        W_new = np.concatenate((W_new, W[:,new]), axis=1)
                        data_id_new = np.concatenate((data_id_new, data_id[new]), axis=0)
                        val_new = np.concatenate((val_new, vals[new]), axis=0)
                    else:
                        W_new = W[:,new]
                        data_id_new = data_id[new]
                        val_new = vals[new]
                        num_new += W_new.shape[1]

        if num_matched > 0 and num_new > 0:
            [col_id_new, c] = sort_unmatched_columns(W_new, eps, d, c)       
            W_all = np.concatenate((W_match, W_new), axis=1)
            col_id_all = np.concatenate((col_id_match, col_id_new), axis=0)
            data_id_all = np.concatenate((data_id_match, data_id_new), axis=0)
            val_all = np.concatenate((val_match, val_new), axis=0)          
        elif num_matched > 0 and num_new == 0:
            W_all = W_match
            col_id_all = col_id_match
            data_id_all = data_id_match
            val_all = val_match     
        elif num_matched == 0 and num_new > 0:
            [col_id_all, c] = sort_unmatched_columns(W_new, eps, d, c)
            W_all = W_new
            data_id_all = data_id_new
            val_all = val_new                       
        elif num_matched == 0 and num_new == 0:
            print("No partial supports recovered, terminating algorithm")
            frob_error_series[epoch:] = frob_error_series[epoch-1]
            A_entries[epoch:] = A_entries[epoch-1]
            X_entries[epoch:] = X_entries[epoch-1]
            total_entries[epoch:] = total_entries[epoch-1]
            exit_program = True
        if exit_program == False:
            [A_rec, X_rec] = update_reconstruction(W_all, col_id_all, data_id_all, val_all, A_rec, X_rec)
            R = Y - A_rec@X_rec
            R[np.absolute(R)<tol] = 0
            frob_error_series[epoch] = np.sqrt(sum(sum(R**2)))
            A_entries[epoch] = np.count_nonzero(A_rec)
            X_entries[epoch] = np.count_nonzero(X_rec)
            total_entries[epoch] = A_entries[epoch] + X_entries[epoch]    
            print('Epoch ', str.format('{0:.0f}', epoch), " processed, l_2 error = ", str.format('{0:.2f}', 100*frob_error_series[epoch]/Y_frob), '%, A l_0 error =', str.format('{0:.2f}', 100*(A_sparsity - A_entries[epoch])/A_sparsity), '%, X l_0 error =', str.format('{0:.2f}', 100*(X_sparsity - X_entries[epoch])/X_sparsity), '%.')
            if epoch == max_epoch:
                print("Maximum number of epochs reached.")
            epoch +=1
    
    end_time = timer()
    comp_time = end_time - start_time
    return [A_rec, X_rec, frob_error_series, total_entries, A_entries, X_entries, comp_time]

# %%
def EBR_l0(Y,N,m,n,d,k,eps,max_epochs,A_sparsity,X_sparsity,Y_frob, alpha):
    epoch = 0
    c = 0
    tol = 10**-8 # make sure is smaller than 1
    exit_program=False  
    A_rec = np.zeros((m,n))
    X_rec = np.zeros((n,N))
    frob_error_series = np.ones(max_epoch)
    A_entries = np.zeros(max_epoch)
    X_entries = np.zeros(max_epoch)
    total_entries = np.zeros(max_epoch)
    R = copy.deepcopy(Y)    
    start_time = timer()
    while epoch < max_epoch and frob_error_series[epoch] > tol and exit_program==False:            
        num_matched = 0
        num_new = 0    
        for i in range(N):
            [W, A_rec[:,:c], match_check, match_col_id, data_id, vals, supports_found]=process_column2(R[:,i], A_rec[:,:c], X_rec[:,i], m, eps, d, k, c, i)
            if supports_found == True:
                matches = np.where(match_check==1)[0]
                new = np.where(match_check==0)[0]
                if len(matches)>0:
                    if num_matched > 0:
                        W_match = np.concatenate((W_match, W[:,matches]), axis=1)
                        col_id_match = np.concatenate((col_id_match, match_col_id[matches]), axis=0)
                        data_id_match = np.concatenate((data_id_match, data_id[matches]), axis=0)
                        val_match = np.concatenate((val_match, vals[matches]), axis=0)
                    else:
                        W_match = W[:,matches]
                        col_id_match = match_col_id[matches]
                        data_id_match = data_id[matches]
                        val_match = vals[matches]
                        num_matched += W_match.shape[1]

                if len(new)>0:
                    if num_new > 0:
                        W_new = np.concatenate((W_new, W[:,new]), axis=1)
                        data_id_new = np.concatenate((data_id_new, data_id[new]), axis=0)
                        val_new = np.concatenate((val_new, vals[new]), axis=0)
                    else:
                        W_new = W[:,new]
                        data_id_new = data_id[new]
                        val_new = vals[new]
                        num_new += W_new.shape[1]

        if num_matched > 0 and num_new > 0:
            [col_id_new, c] = sort_unmatched_columns(W_new, eps, d, c)       
            W_all = np.concatenate((W_match, W_new), axis=1)
            col_id_all = np.concatenate((col_id_match, col_id_new), axis=0)
            data_id_all = np.concatenate((data_id_match, data_id_new), axis=0)
            val_all = np.concatenate((val_match, val_new), axis=0)          
        elif num_matched > 0 and num_new == 0:
            W_all = W_match
            col_id_all = col_id_match
            data_id_all = data_id_match
            val_all = val_match     
        elif num_matched == 0 and num_new > 0:
            [col_id_all, c] = sort_unmatched_columns(W_new, eps, d, c)
            W_all = W_new
            data_id_all = data_id_new
            val_all = val_new                       
        elif num_matched == 0 and num_new == 0:
            print("No partial supports recovered, terminating algorithm")
            frob_error_series[epoch:] = frob_error_series[epoch-1]
            A_entries[epoch:] = A_entries[epoch-1]
            X_entries[epoch:] = X_entries[epoch-1]
            total_entries[epoch:] = total_entries[epoch-1]
            exit_program = True    
        
        if exit_program == False:
            [A_rec, X_rec] = update_reconstruction(W_all, col_id_all, data_id_all, val_all, A_rec, X_rec)  
          
            ### RUN l-0 HERE using completed columns ####            
            # Identify the completed columns of A at this iteration
            col_sumA = np.sum(A_rec, axis = 0)
            col_sumA[col_sumA != d] = 0
            comp = np.nonzero(col_sumA)[0]
            num_comp = len(comp)
            
            # Compute the residual based on the completed columns only
            R_l0 = Y - A_rec[:,comp]@X_rec[comp, :]
            R_l0[np.absolute(R_l0)<tol] = 0 
            # Identify which columns of the residual need to still try and decode
            col_sumR = np.sum(np.absolute(R_l0), axis = 0)
            col_sumR[np.absolute(col_sumR) < tol] = 0
            not_dec = np.nonzero(col_sumR)[0]
            num_2_process = len(not_dec)
            
            print("Running l0 decode on epoch ", str.format('{0:.0f}', epoch+1), ': n. of data points of Y still to decode = ', str.format('{0:.0f}', num_2_process), ", n. columns of A completed = ", str.format('{0:.0f}', num_comp),)       
            # Iterate through each column in turn and run l0 decode
            for j in range(num_2_process):
                X_l0_update = l0_decode(R_l0[:,not_dec[j]], A_rec[:,comp], num_comp, alpha)
                X_rec[comp, not_dec[j]] = X_rec[comp, not_dec[j]] + X_l0_update
                if np.mod(int(not_dec[j]),np.ceil(num_2_process/5)) == 0:
                    print("Processed ", str.format('{0:.0f}', j), " data points out of ", str.format('{0:.0f}', num_2_process))
            ############################################   
            
            R = Y - A_rec@X_rec
            R[np.absolute(R)<tol] = 0            
            frob_error_series[epoch] = np.sqrt(sum(sum(R**2)))
            A_entries[epoch] = np.count_nonzero(A_rec)
            X_entries[epoch] = np.count_nonzero(X_rec)
            total_entries[epoch] = A_entries[epoch] + X_entries[epoch]    
            print('Epoch ', str.format('{0:.0f}', epoch), " processed, l_2 error = ", str.format('{0:.2f}', 100*frob_error_series[epoch]/Y_frob), '%, A l_0 error =', str.format('{0:.2f}', 100*(A_sparsity - A_entries[epoch])/A_sparsity), '%, X l_0 error =', str.format('{0:.2f}', 100*(X_sparsity - X_entries[epoch])/X_sparsity), '%.')
            if epoch == max_epoch:
                print("Maximum number of epochs reached.")
            epoch +=1
    
    end_time = timer()
    comp_time = end_time - start_time
    return [A_rec, X_rec, frob_error_series, total_entries, A_entries, X_entries, comp_time]

# %% [markdown]
# # Experiments analyzing performance of EBR

# %% [markdown]
# ## Generate synthetic data to run algorithms on

# %% [markdown]
# #### Generating a valid dictionary and data

# %%
# Dictionary parameters parameters
n = 1200
# beta = 900

m = 900
d = 10;
eps = 1/6;
N = 200


# Generate a dictionary and check that passes necessary test.
num_generations = 0
passed = False
while passed==False and num_generations < 100:
    A = generate_exp_dictionary2(m,n,d);
    passed = check_dictionary(eps,n,d,A)
    num_generations += 1
if passed == True:
    print("Generated dictionary that passes the coherency test")
else:
    print("Failed to generate dictionary that passes the coherency test, consider different parameters")

A_sparsity = np.count_nonzero(A)
# Out:
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# Generation error, A is not expander for this value of epsilon, mu_A =  5.00 , tau =  3.33 .
# Generation error, A is not expander for this value of epsilon, mu_A =  4.00 , tau =  3.33 .
# A passes coherence test, mu_A =  3.00 , tau =  3.33 .
# Generated dictionary that passes the coherency test

# %% [markdown]
# #### Generate data using dictionary

# %%
##### GENERATE LATENT REPRESENTATION
b1=1;
b2=5;
# k = [int(np.ceil(0.01*n)), int(np.ceil(0.04*n)), int(np.ceil(0.07*n)), int(np.ceil(0.1*n))]
k = [int(np.ceil(0.01*n)), int(np.ceil(0.03*n)), int(np.ceil(0.05*n)), int(np.ceil(0.07*n))]
X = np.zeros((len(k), n, N))
Y = np.zeros((len(k), m, N))
Y_frob = np.zeros(len(k))
X_sparsity = np.zeros(len(k))
number_k_to_process = len(k)

for j in range(len(k)):
    for i in range(N):
        X[j,:,i] = generate_latent(n,k[j],b1,b2)
    Y[j] = A@X[j]
    Y_frob[j] = np.sqrt(sum(sum(Y[j]**2)))
    X_sparsity[j] = k[j]*N

# %% [markdown]
# ## Check that l0 function is working as it should be

# %%
ind = 3
alpha=3
N_check = 1

Z = np.zeros((n, N_check))
offset = 28


for j in range(N_check):
    Z[:,j] = l0_decode(Y[ind,:,offset+j], A, n, alpha)
    if np.mod(j,np.ceil(N_check/10)) == 0:
        print(j)
        
check_recon_X(X[ind,:,offset:offset+N_check],Z,np.eye(n),N_check,k[ind],n)
# Out:
# 0
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
# array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]])

# %% [markdown]
# ## Running EBR to recover A and X varying $k/n$

# %%
if passed == True:
    eps = 1/6;
    max_epoch = 8
    tol = 10**-8    
    comp_time = np.zeros(len(k))   
    A_rec = np.zeros((len(k),m,n))
    X_rec = np.zeros((len(k),n,N))
    frob_error_series = np.ones((len(k), max_epoch))
    A_entries = np.zeros((len(k), max_epoch))
    X_entries = np.zeros((len(k), max_epoch))
    total_entries = np.zeros((len(k), max_epoch))
    for j in range(number_k_to_process):
        print("Solving problem with k/n = ", str.format('{0:.1f}', 100*k[j]/n), '%, N = ', str.format('{0:.0f}', N))       
        [A_rec[j], X_rec[j], frob_error_series[j], total_entries[j], A_entries[j], X_entries[j], comp_time[j]] = EBR(Y[j],N,m,n,d,k[j],eps,max_epoch,A_sparsity,X_sparsity[j],Y_frob[j])
        print("")
        P = check_recon_A(A, A_rec[j],d,eps,n)
        print("")
        check_recon_X(X[j],X_rec[j],P,N,k[j],n)
        print("")
# Out:
# Solving problem with k/n =  1.0 %, N =  200
# Epoch  0  processed, l_2 error =  17.74 %, A l_0 error = 17.27 %, X l_0 error = 1.71 %.
# Epoch  1  processed, l_2 error =  7.48 %, A l_0 error = 14.61 %, X l_0 error = 0.04 %.
# Epoch  2  processed, l_2 error =  6.05 %, A l_0 error = 14.48 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 80.7 % of columns fully formed.
# 5.6 % of columns partially formed.
# 13.8 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 14 % of entries missing in total.
# 88 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
#
# Solving problem with k/n =  3.0 %, N =  200
# Epoch  0  processed, l_2 error =  62.31 %, A l_0 error = 4.97 %, X l_0 error = 37.94 %.
# Epoch  1  processed, l_2 error =  34.55 %, A l_0 error = 1.01 %, X l_0 error = 11.86 %.
# Epoch  2  processed, l_2 error =  14.45 %, A l_0 error = 0.33 %, X l_0 error = 1.93 %.
# Epoch  3  processed, l_2 error =  5.32 %, A l_0 error = 0.22 %, X l_0 error = 0.21 %.
# Epoch  4  processed, l_2 error =  3.83 %, A l_0 error = 0.17 %, X l_0 error = 0.11 %.
# Epoch  5  processed, l_2 error =  2.79 %, A l_0 error = 0.17 %, X l_0 error = 0.06 %.
# Epoch  6  processed, l_2 error =  0.41 %, A l_0 error = 0.17 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 99.8 % of columns fully formed.
# 0.1 % of columns partially formed.
# 0.2 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 0 % of entries missing in total.
# 1 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  200
# Epoch  0  processed, l_2 error =  87.92 %, A l_0 error = 17.67 %, X l_0 error = 76.29 %.
# Epoch  1  processed, l_2 error =  82.94 %, A l_0 error = 9.47 %, X l_0 error = 67.74 %.
# Epoch  2  processed, l_2 error =  79.49 %, A l_0 error = 6.07 %, X l_0 error = 62.37 %.
# Epoch  3  processed, l_2 error =  76.80 %, A l_0 error = 4.16 %, X l_0 error = 58.20 %.
# Epoch  4  processed, l_2 error =  74.08 %, A l_0 error = 3.04 %, X l_0 error = 54.53 %.
# Epoch  5  processed, l_2 error =  71.77 %, A l_0 error = 2.15 %, X l_0 error = 51.05 %.
# Epoch  6  processed, l_2 error =  69.54 %, A l_0 error = 1.52 %, X l_0 error = 47.86 %.
# Epoch  7  processed, l_2 error =  67.43 %, A l_0 error = 1.27 %, X l_0 error = 45.12 %.
#
# Checking reconstruction of A.
# 93.8 % of columns fully formed.
# 5.8 % of columns partially formed.
# 0.4 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 1 % of entries missing in total.
# 103 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 54.9 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 45.1 % of entries missing.
#
# Solving problem with k/n =  7.1 %, N =  200
# Epoch  0  processed, l_2 error =  97.50 %, A l_0 error = 56.33 %, X l_0 error = 94.21 %.
# Epoch  1  processed, l_2 error =  97.33 %, A l_0 error = 54.01 %, X l_0 error = 93.84 %.
# Epoch  2  processed, l_2 error =  97.32 %, A l_0 error = 53.87 %, X l_0 error = 93.82 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 11.2 % of columns fully formed.
# 46.0 % of columns partially formed.
# 42.8 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 54 % of entries missing in total.
# 1324 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 6.2 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 93.8 % of entries missing.

# %%
plt.figure(1).clear()

plot_A_entries = 100*A_entries/A_sparsity

plot_X_entries = np.zeros((len(k), max_epoch))
plot_frob = np.zeros((len(k), max_epoch))

for j in range(number_k_to_process):
    plot_X_entries[j,:] = 100*X_entries[j,:]/X_sparsity[j]
plot_epoch = max_epoch

print("Running times:")
print("k/n=%s %%, %s s"%(100*k[0]/n, comp_time[0]))
print("k/n=%s %%, %s s"%(100*k[1]/n, comp_time[1]))      
print("k/n=%s %%, %s s"%(100*k[2]/n, comp_time[2]))  

plt.figure(1)
plt.figure(figsize=(15,20))
plt.subplot(2,2,1)
plt.plot(np.arange(max_epoch)+1, plot_A_entries[0], 'g-', label="A, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[1], 'b-', label="A, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[2], 'r-', label="A, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[3], 'k-', label="A, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBR varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of A recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.subplot(2,2,2)
plt.plot(np.arange(max_epoch)+1, plot_X_entries[0], 'g-',label="X, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[1], 'b-',label="X, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[2], 'r-',label="X, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[3], 'k-',label="X, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBR varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of X recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
# plt.savefig('./figures_ACHA/EBR_performance.eps', format='eps', bbox_inches='tight')
# Out:
# Running times:
# k/n=1.0 %, 7.659246439 s
# k/n=3.0 %, 33.489057793 s
# k/n=5.0 %, 146.283399408 s

# %% [markdown]
# ## Running EBR-l0 to recover A and X varying $k/n$

# %%
# Extra parameters required for EBR-l0
alpha=3

# Run EBR interweaved with l-0 decode
if passed == True:
    eps = 1/6;
    tol = 10**-8
    comp_time_l0 = np.zeros(len(k))
    A_rec_l0 = np.zeros((len(k),m,n))
    X_rec_l0 = np.zeros((len(k),n,N))
    frob_error_series_l0 = np.ones((len(k), max_epoch))
    A_entries_l0 = np.zeros((len(k), max_epoch))
    X_entries_l0 = np.zeros((len(k), max_epoch))
    total_entries_l0 = np.zeros((len(k), max_epoch))   
    for j in range(number_k_to_process):
        print("Solving problem with k/n = ", str.format('{0:.1f}', 100*k[j]/n), '%, N = ', str.format('{0:.0f}', N))
        [A_rec_l0[j], X_rec_l0[j], frob_error_series_l0[j], total_entries_l0[j], A_entries_l0[j], X_entries_l0[j], comp_time_l0[j]] = EBR_l0(Y[j],N,m,n,d,k[j],eps,max_epoch,A_sparsity,X_sparsity[j],Y_frob[j],alpha)
        print("")
        P = check_recon_A(A, A_rec_l0[j],d,eps,n)
        print("")
        check_recon_X(X[j],X_rec_l0[j],P,N,k[j],n)
        print("")
# Out:
# Solving problem with k/n =  1.0 %, N =  200
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  157 , n. columns of A completed =  783
# Processed  0  data points out of  157
# Processed  27  data points out of  157
# Processed  48  data points out of  157
# Processed  74  data points out of  157
# Processed  100  data points out of  157
# Processed  125  data points out of  157
# Epoch  0  processed, l_2 error =  14.43 %, A l_0 error = 17.27 %, X l_0 error = 0.50 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  45 , n. columns of A completed =  967
# Processed  0  data points out of  45
# Processed  6  data points out of  45
# Processed  7  data points out of  45
# Processed  13  data points out of  45
# Processed  23  data points out of  45
# Processed  31  data points out of  45
# Processed  32  data points out of  45
# Processed  33  data points out of  45
# Processed  37  data points out of  45
# Processed  38  data points out of  45
# Processed  44  data points out of  45
# Epoch  1  processed, l_2 error =  6.15 %, A l_0 error = 14.50 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 80.8 % of columns fully formed.
# 5.4 % of columns partially formed.
# 13.8 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 14 % of entries missing in total.
# 87 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
#
# Solving problem with k/n =  3.0 %, N =  200
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  200 , n. columns of A completed =  946
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.22107
# Processed  0  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.11940
# Processed  40  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.19732
# Processed  80  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.33150
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.41828
# Processed  120  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.61943
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.12429
# Processed  160  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.78052
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  32.94328
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.30821
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.67886
# Epoch  0  processed, l_2 error =  29.58 %, A l_0 error = 4.97 %, X l_0 error = 7.75 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  31 , n. columns of A completed =  1183
# Processed  0  data points out of  31
# Processed  10  data points out of  31
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.32694
# Processed  17  data points out of  31
# Processed  20  data points out of  31
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.15521
# Processed  25  data points out of  31
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.37221
# Epoch  1  processed, l_2 error =  3.54 %, A l_0 error = 0.30 %, X l_0 error = 0.01 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  7 , n. columns of A completed =  1194
# Processed  1  data points out of  7
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.27409
# Processed  2  data points out of  7
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.23282
# Processed  6  data points out of  7
# Epoch  2  processed, l_2 error =  3.86 %, A l_0 error = 0.20 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  5 , n. columns of A completed =  1195
# Processed  0  data points out of  5
# Processed  1  data points out of  5
# Processed  2  data points out of  5
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  40.31042
# Processed  3  data points out of  5
# Processed  4  data points out of  5
# Epoch  3  processed, l_2 error =  4.75 %, A l_0 error = 0.19 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  5 , n. columns of A completed =  1195
# Processed  0  data points out of  5
# Processed  1  data points out of  5
# Processed  2  data points out of  5
# Processed  3  data points out of  5
# Processed  4  data points out of  5
# Epoch  4  processed, l_2 error =  0.87 %, A l_0 error = 0.19 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 99.6 % of columns fully formed.
# 0.2 % of columns partially formed.
# 0.2 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 0 % of entries missing in total.
# 3 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
#
# Solving problem with k/n =  5.0 %, N =  200
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  200 , n. columns of A completed =  614
# Processed  0  data points out of  200
# Processed  40  data points out of  200
# Processed  80  data points out of  200
# Processed  120  data points out of  200
# Processed  160  data points out of  200
# Epoch  0  processed, l_2 error =  61.16 %, A l_0 error = 17.67 %, X l_0 error = 36.83 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  191 , n. columns of A completed =  1190
# Processed  0  data points out of  191
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.10603
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.04858
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.87847
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.19380
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.34254
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.18017
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.80490
# Processed  37  data points out of  191
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  3.26040
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.03833
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.08758
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.57989
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.99724
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.70988
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.54572
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.06608
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  4.35874
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.34793
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.51992
# Processed  75  data points out of  191
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.29275
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.06334
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.54618
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  3.95981
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.99769
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.76233
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.60090
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.85421
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.70887
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  5.02525
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.61578
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.91862
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.50333
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.27049
# Processed  113  data points out of  191
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.17089
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.61614
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  3.63795
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.56038
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.74169
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.24026
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.83299
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.45090
# Processed  149  data points out of  191
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.22207
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  5.76290
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  4.77547
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.10272
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.41385
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.14502
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.40732
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.30915
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  3.86721
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.47960
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  5.42724
# Processed  186  data points out of  191
# Epoch  1  processed, l_2 error =  8.61 %, A l_0 error = 0.17 %, X l_0 error = 0.23 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  51 , n. columns of A completed =  1200
# Processed  6  data points out of  51
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.52079
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.17516
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.51425
# Processed  13  data points out of  51
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.72348
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.30402
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.62709
# Processed  19  data points out of  51
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.91962
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.06701
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.45345
# Processed  24  data points out of  51
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.77834
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.05049
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.27589
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.66599
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.52581
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.55093
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.61830
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.73442
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.85447
# Epoch  2  processed, l_2 error =  4.73 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  18 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.78119
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.26274
# Processed  1  data points out of  18
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.08822
# Processed  4  data points out of  18
# Processed  5  data points out of  18
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.91384
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.88672
# Epoch  3  processed, l_2 error =  3.15 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  5 , n. columns of A completed =  1200
# Processed  0  data points out of  5
# Processed  1  data points out of  5
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.45297
# Processed  2  data points out of  5
# Processed  3  data points out of  5
# Processed  4  data points out of  5
# Epoch  4  processed, l_2 error =  2.10 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  6 : n. of data points of Y still to decode =  1 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.81771
# Processed  0  data points out of  1
# Epoch  5  processed, l_2 error =  2.67 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  7 : n. of data points of Y still to decode =  1 , n. columns of A completed =  1200
# Processed  0  data points out of  1
# Epoch  6  processed, l_2 error =  0.00 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# No partial supports recovered, terminating algorithm
#
# Checking reconstruction of A.
# 100.0 % of columns fully formed.
# 0.0 % of columns partially formed.
# 0.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 0 % of entries missing in total.
# 0 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.
#
# Solving problem with k/n =  7.1 %, N =  200
# Running l0 decode on epoch  1 : n. of data points of Y still to decode =  200 , n. columns of A completed =  125
# Processed  0  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  99.60710
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  97.25716
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  83.90015
# Processed  40  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  102.24330
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  90.30213
# Processed  80  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  89.19313
# Processed  120  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  89.20094
# Processed  160  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  93.13673
# Epoch  0  processed, l_2 error =  92.89 %, A l_0 error = 56.33 %, X l_0 error = 85.39 %.
# Running l0 decode on epoch  2 : n. of data points of Y still to decode =  200 , n. columns of A completed =  253
# Processed  0  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  94.60459
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  78.24882
# Processed  40  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  94.67685
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  86.73765
# Processed  80  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  81.83635
# Processed  120  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  84.60790
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  77.89235
# Processed  160  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  87.52503
# Epoch  1  processed, l_2 error =  85.89 %, A l_0 error = 38.48 %, X l_0 error = 72.85 %.
# Running l0 decode on epoch  3 : n. of data points of Y still to decode =  200 , n. columns of A completed =  534
# Processed  0  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  72.85038
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  78.50064
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  62.51727
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  61.05249
# Processed  40  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  68.46622
# Processed  80  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  65.04725
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  65.22513
# Processed  120  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  63.39160
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  66.14598
# Processed  160  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  73.54275
# Epoch  2  processed, l_2 error =  69.67 %, A l_0 error = 20.43 %, X l_0 error = 47.88 %.
# Running l0 decode on epoch  4 : n. of data points of Y still to decode =  200 , n. columns of A completed =  1107
# Processed  0  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.08481
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.47111
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.98022
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.62083
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.76072
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.28257
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.07235
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.94696
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.28108
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.59112
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.71491
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.91027
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.20921
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.21188
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  27.36217
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.16139
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.25231
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.72685
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.01925
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.20469
# Processed  40  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.88402
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.63557
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.51006
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.16109
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.87590
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.99534
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  32.67882
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.14933
# Processed  80  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.22601
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.70839
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.91675
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.65340
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.07329
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  27.98631
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.07190
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  27.81060
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.66183
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.95673
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.25157
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.10215
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.15250
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.82185
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.87252
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.97519
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.67040
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  35.74816
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  34.84457
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.75997
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.00712
# Processed  120  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.16585
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.51578
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.80209
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.81961
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.19371
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.00016
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.76550
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.06032
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  37.60685
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.96113
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.96147
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  36.13516
# Processed  160  data points out of  200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.52273
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.05899
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  13.89042
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.88301
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.55621
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.64986
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.72524
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  37.57964
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.45336
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.51944
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.14076
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.95128
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.08014
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.76513
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  37.53759
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.59532
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.62813
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.25056
# Epoch  3  processed, l_2 error =  24.41 %, A l_0 error = 1.27 %, X l_0 error = 5.21 %.
# Running l0 decode on epoch  5 : n. of data points of Y still to decode =  85 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.88764
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.54536
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.46579
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.27920
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.51255
# Processed  9  data points out of  85
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.12665
# Processed  16  data points out of  85
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.63646
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  5.40900
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  26.01866
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.66557
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.11165
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.20204
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.08957
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  22.15842
# Processed  35  data points out of  85
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.26386
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  16.83083
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  36.27293
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.70700
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.34149
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  50.18967
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.46695
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  19.37353
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.61500
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  20.39547
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  8.36588
# Processed  59  data points out of  85
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  24.04009
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.43684
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  7.58476
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  30.80619
# Processed  69  data points out of  85
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.58497
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.14187
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  18.88995
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  15.43364
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.73945
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.69733
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.90824
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  6.66902
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.32773
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.19654
# Epoch  4  processed, l_2 error =  8.96 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  6 : n. of data points of Y still to decode =  39 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.81804
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.19869
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.45468
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.25045
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  39.02800
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  46.66747
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.20204
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  33.23762
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  34.89579
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  21.03854
# Processed  15  data points out of  39
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  42.57837
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  9.70043
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.06029
# Processed  23  data points out of  39
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  12.54882
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  38.15526
# Processed  26  data points out of  39
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  11.37714
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  46.20928
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  31.71280
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  28.33493
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.15046
# Processed  32  data points out of  39
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.00353
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  10.12918
# Epoch  5  processed, l_2 error =  9.79 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  7 : n. of data points of Y still to decode =  22 , n. columns of A completed =  1200
# Processed  0  data points out of  22
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  14.93158
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  23.27291
# Processed  5  data points out of  22
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.20204
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  44.31683
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  46.52772
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  25.24624
# Processed  13  data points out of  22
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  50.87369
# Processed  14  data points out of  22
# Processed  15  data points out of  22
# Processed  16  data points out of  22
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  42.28374
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  37.77990
# Epoch  6  processed, l_2 error =  8.11 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
# Running l0 decode on epoch  8 : n. of data points of Y still to decode =  9 , n. columns of A completed =  1200
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  29.09114
# Processed  1  data points out of  9
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  17.20204
# Processed  5  data points out of  9
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  63.59211
# Processed  6  data points out of  9
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  52.85467
# Warning: max number of iterations of while loop in l0 decode step reached.
# Percentage improvement in residual from penultimate iteration:  0.00000
# Size of final residual:  47.22488
# Processed  8  data points out of  9
# Epoch  7  processed, l_2 error =  7.60 %, A l_0 error = 0.00 %, X l_0 error = 0.00 %.
#
# Checking reconstruction of A.
# 100.0 % of columns fully formed.
# 0.0 % of columns partially formed.
# 0.0 % of columns have no entries.
# 100.0 % of reconstructed (fully or partially) columns match with a column in target matrix.
# 0 % of entries missing in total.
# 0 entries missing in matched columns.
# 0 entries wrong in matched columns.
#
# Checking the values of X recovered.
# Column number =  36 , row number =  215 , true value =  1.83988515939 value found =  11.0393109563
# Column number =  67 , row number =  958 , true value =  -2.71988055715 value found =  2.71988055715
# Column number =  160 , row number =  929 , true value =  4.02191799602 value found =  24.1315079761
# Column number =  173 , row number =  242 , true value =  -3.34282297371 value found =  -20.0569378422
# Column number =  174 , row number =  839 , true value =  2.98676358687 value found =  17.9205815212
# 100.0 % of entries correctly recovered.
# 0.0 % of entries in correct location but have wrong value for location.
# 0.0 % of entries missing.

# %%
plt.figure(2).clear()

plot_X_entries_l0 = np.zeros((len(k), max_epoch))
plot_A_entries_l0 = 100*A_entries_l0/A_sparsity

for j in range(number_k_to_process):
    plot_X_entries_l0[j,:] = 100*X_entries_l0[j,:]/X_sparsity[j]

plot_epoch = max_epoch

print("Running times:")
print("k/n=%s %%, %s s"%(100*k[0]/n, comp_time[0]))
print("k/n=%s %%, %s s"%(100*k[1]/n, comp_time[1]))      
print("k/n=%s %%, %s s"%(100*k[2]/n, comp_time[2]))  

plt.figure(2)
plt.figure(figsize=(15,20))
plt.subplot(2,2,1)
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[0], 'g--', label="A, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[1], 'b--', label="A, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[2], 'r--', label="A, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[3], 'k--', label="A, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBR-l0 varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of A recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.subplot(2,2,2)
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[0], 'g--',label="X, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[1], 'b--',label="X, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[2], 'r--',label="X, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[3], 'k--',label="X, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBR-l0 varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of X recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.savefig('./figures_ACHA/EBR_l0_performance.eps', format='eps', bbox_inches='tight')
# Out:
# Running times:
# k/n=1.0 %, 7.659246439 s
# k/n=3.0 %, 33.489057793 s
# k/n=5.0 %, 146.283399408 s

# %% [markdown]
# ## Side by side comparison of EBR vs EBR-l0

# %%
plot_epoch = 6

plt.figure(3)
plt.figure(figsize=(15,20))
plt.subplot(2,2,1)
plt.plot(np.arange(max_epoch)+1, plot_A_entries[0], 'g-', label="EBR, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[1], 'b-', label="EBR, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[2], 'r-', label="EBR, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries[3], 'k-', label="EBR, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[0], 'g--', label="EBR-l0, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[1], 'b--', label="EBR-l0, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[2], 'r--', label="EBR-l0, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_A_entries_l0[3], 'k--', label="EBR-l0, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.grid(True)
plt.title('Percentage of entries of A recovered by EBR and EBR-l0 varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of A recovered (%)')
plt.xlim(1,plot_epoch)
plt.legend()
plt.subplot(2,2,2)
plt.plot(np.arange(max_epoch)+1, plot_X_entries[0], 'g-',label="EBR, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[1], 'b-',label="EBR, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[2], 'r-',label="EBR, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries[3], 'k-',label="EBR, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[0], 'g--',label="EBR-l0, k/n=%s %%"%(int(round(100*k[0]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[1], 'b--',label="EBR-l0, k/n=%s %%"%(int(round(100*k[1]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[2], 'r--',label="EBR-l0, k/n=%s %%"%(int(round(100*k[2]/n, 0))))
plt.plot(np.arange(max_epoch)+1, plot_X_entries_l0[3], 'k--',label="EBR-l0, k/n=%s %%"%(int(round(100*k[3]/n, 0))))
plt.grid(True)
plt.title('Percentage of entries of X recovered by EBR and EBR-l0 varying k/n')
plt.xlabel('Epochs')
plt.ylabel('Entries of X recovered (%)')
plt.xlim(1,plot_epoch)
# plt.legend()
plt.savefig('./figures_ACHA/EBR_vs_EBR_l0_comparison.eps', format='eps', bbox_inches='tight')
